# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# &lt;AxesSubplot:xlabel=&#39;survived&#39;, ylabel=&#39;fare&#39;&gt;
# &lt;Figure size 2160x360 with 5 Axes&gt;

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: &quot;sequential&quot;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6922 - accuracy: 0.5861
# Epoch 2/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6900 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6854 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6755 - accuracy: 0.6124
# Epoch 5/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6579 - accuracy: 0.7321
# Epoch 6/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6319 - accuracy: 0.7512
# Epoch 7/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.7667
# Epoch 8/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5665 - accuracy: 0.7656
# Epoch 9/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.7679
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5123 - accuracy: 0.7739
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.7727
# Epoch 12/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.7715
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4812 - accuracy: 0.7799
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.7847
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4719 - accuracy: 0.7835
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.7823
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4661 - accuracy: 0.7835
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.7835
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.7835
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.7895
# Epoch 21/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4584 - accuracy: 0.7895
# Epoch 22/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4577 - accuracy: 0.7835
# Epoch 23/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4577 - accuracy: 0.7811
# Epoch 24/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.7859
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4548 - accuracy: 0.7823
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.7847
# Epoch 27/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4531 - accuracy: 0.7847
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4522 - accuracy: 0.7835
# Epoch 29/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7811
# Epoch 30/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.7847
# Epoch 31/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4502 - accuracy: 0.7871
# Epoch 32/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4508 - accuracy: 0.7883
# Epoch 33/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4499 - accuracy: 0.7883
# Epoch 34/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.7859
# Epoch 35/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.7823
# Epoch 36/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4486 - accuracy: 0.7895
# Epoch 37/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4487 - accuracy: 0.7871
# Epoch 38/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.7895
# Epoch 39/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7859
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7883
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7895
# Epoch 42/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4488 - accuracy: 0.7895
# Epoch 43/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4481 - accuracy: 0.7883
# Epoch 44/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.7931
# Epoch 45/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4473 - accuracy: 0.7883
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7895
# Epoch 47/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.7883
# Epoch 48/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.7871
# Epoch 49/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4475 - accuracy: 0.7895
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.7919
# &lt;tensorflow.python.keras.callbacks.History at 0x7fb1e0604df0&gt;

# %%
y_pred = model.predict_classes(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# WARNING:tensorflow:From &lt;ipython-input-16-6007bb8697bc&gt;:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) &gt; 0.5).astype(&quot;int32&quot;)`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 0.7799043062200957
